# %% [markdown]
# print("meu primeiro codigo")

# %%
import pyautogui
import time

link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga"

pyautogui.PAUSE = 0.5

pyautogui.press("win")
pyautogui.write("chrome")
pyautogui.press("enter")
pyautogui.hotkey("win" ,"up")

time.sleep(0.5)
pyautogui.write(link)
pyautogui.press("enter")
time.sleep(3)

pyautogui.click(x=616, y=340, clicks = 2) #Abre a pasta do arquivo
time.sleep(1)
pyautogui.click(x=1711, y=337) # Realizar o donwload
time.sleep(3) #tempo de baixar o arquivo

# %%
#localização do mouse na tela
time.sleep(5)
print(pyautogui.position())
# Out:
# Point(x=1711, y=337)

# %%
import pandas
# Passo 4:Calcular os indicadores (faturamento e quantidade de produtos vendidos)
# Abrir base de dados
caminho = r"C:\Users\DBA\Downloads\Vendas - Dez.xlsx"
tabela = pandas.read_excel(caminho)
# Ver as informações da base de dados
display(tabela)
# Somar o faturamento de todos os produtos
faturamento = tabela["Valor Final"].sum()
# Somar a quantidade de produtos
qtde_produtos = tabela["Quantidade"].sum()

print(faturamento)
print(qtde_produtos)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
import pyperclip
# passo 5: enviar as informações por email
#abrir uma nova aba
pyautogui.hotkey("ctrl" , "t")

#entrar no email
pyautogui.write("https://mail.google.com/")
pyautogui.press("enter")
time.sleep(2)

#clicar no botao escrever
pyautogui.click(x=130, y=194)
time.sleep(2)

#Para quem enviar
pyautogui.write("baptista.sql@gmail.com")
pyautogui.press("tab") # Seleciona o email
pyautogui.press("tab") # passar para o campo do assunto
#Qual o assunto
pyperclip.copy("Relátorio de vendas")
pyautogui.hotkey("ctrl" , "v")
pyautogui.press("tab")
#Qual o corpo do email
texto = f"""
Prezados,

Segue o relatório de vendas de hoje.

Faturamento: R${faturamento:,.2f}
Quantidade de produtos vendidos: {qtde_produtos:,}

Qualquer duvida estou a disposição.
abs,
Fábio Baptista
"""
pyperclip.copy(texto)
pyautogui.hotkey("ctrl" , "v")
time.sleep(2)

#Enviar o email
pyautogui.click(x=1300, y=1015)
#teste git

# %% [markdown]
# re

# %% [markdown]
# HTTPS:MAIL>GOOGLE>COM#
